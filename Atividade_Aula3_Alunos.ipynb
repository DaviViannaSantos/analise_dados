# %%
import pandas as pd

# %%
path = "Tabela_3_Areas_gerais.xlsx"

# %%
formacao_bruto = pd.read_excel(path, header=None)

# %%
formacao_bruto

# %% [markdown]
# A tabela deverá ser dividida em 3
# - homens e mulheres por região com curso superior
# - homens e mulheres por região com curso nas áreas de Ciência, Tecnologia, Engenharias e Matemática
# - homens e mulheres por região com curso nas áreas de Educação, Serviços pessoais, Saúde e Bem-estar

# %% [markdown]
# Exemplo 1

# %%
formacao_total = formacao_bruto.iloc[3:36, 0:4].copy()

# %%
formacao_total.columns = [
    "uf_regiao",
    "total",
    "total_homens",
    "total_mulheres"
]

# %%
formacao_total

# %%
formacao_total["percentual_mulheres"] = ((formacao_total["total_mulheres"] / formacao_total["total"]) * 100).round(2)

formacao_total

# %%
formacao_stem = formacao_bruto.iloc[3:36, [0, 4, 5, 6]].copy()

formacao_stem.columns = [
    "uf_regiao",
    "total",
    "total_homens",
    "total_mulheres"
]

formacao_stem["percentual_mulheres"] = ((formacao_stem["total_mulheres"] / formacao_stem["total"]) * 100).round(2)

formacao_stem

# %%
formacao_humanas_saude = formacao_bruto.iloc[3:36, [0, 7, 8, 9]].copy()

formacao_humanas_saude.columns = [
    "uf_regiao",
    "total",
    "total_homens",
    "total_mulheres"
]

formacao_humanas_saude["percentual_mulheres"] = ((formacao_humanas_saude["total_mulheres"] / formacao_humanas_saude["total"]) * 100).round(2)

formacao_humanas_saude

# %%
path_domicilios = "Tabela_11_Domicilios_Sua_Especialidade.xlsx" 
indicador_2 = pd.read_excel(path_domicilios)

indicador_2 = indicador_2[~indicador_2["uf_regiao"].str.contains(r"\(")]
indicador_2

# %%
indicador_1 = pd.read_excel(path_domicilios, sheet_name=0)

indicador1e2 = pd.merge(indicador_1, indicador_2, on="uf_regiao", how="left")
indicador1e2
